# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv("data_sp500.csv")
df
# Out:
#             Date    SP500  Dividend  Earnings  Consumer Price Index  \
# 0     1871-01-01     4.44      0.26      0.40                 12.46
# 1     1871-02-01     4.50      0.26      0.40                 12.84
# 2     1871-03-01     4.61      0.26      0.40                 13.03
# 3     1871-04-01     4.74      0.26      0.40                 12.56
# 4     1871-05-01     4.86      0.26      0.40                 12.27
# ...          ...      ...       ...       ...                   ...
# 1763  2017-12-01  2664.34     48.93    109.88                246.52
# 1764  2018-01-01  2789.80     49.29       NaN                247.87
# 1765  2018-02-01  2705.16     49.64       NaN                248.99
# 1766  2018-03-01  2702.77     50.00       NaN                249.55
# 1767  2018-04-01  2642.19       NaN       NaN                249.84
#
#       Long Interest Rate  Real Price  Real Dividend  Real Earnings   PE10
# 0                   5.32       89.00           5.21           8.02    NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1768 entries, 0 to 1767
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  1768 non-null   object
#  1   SP500                 1768 non-null   float64
#  2   Dividend              1767 non-null   float64
#  3   Earnings              1764 non-null   float64
#  4   Consumer Price Index  1768 non-null   float64
#  5   Long Interest Rate    1768 non-null   float64
#  6   Real Price            1768 non-null   float64
#  7   Real Dividend         1767 non-null   float64
#  8   Real Earnings         1764 non-null   float64
#  9   PE10                  1648 non-null   float64
# dtypes: float64(9), object(1)
# memory usage: 138.2+ KB

# %%
fig,ax=plt.subplots(figsize=(10,10))
df["SP500"].plot(ax=ax)
plt.show()

# %%
df["SP500_return"]=(df['SP500']-df['SP500'].shift(1))/df["SP500"].shift(1)

# %%
fig,ax=plt.subplots(figsize=(10,6))
df["SP500_return"].plot(ax=ax)
plt.show()

# %%
crisi=df[(df["Date"]>"1910-01-01") & (df["Date"]<"1940-01-01")]
crisi
# Out:
#            Date  SP500  Dividend  Earnings  Consumer Price Index  \
# 469  1910-02-01   9.72      0.45      0.76                  9.90
# 470  1910-03-01   9.96      0.45      0.75                 10.09
# 471  1910-04-01   9.72      0.45      0.75                 10.18
# 472  1910-05-01   9.56      0.45      0.75                  9.99
# 473  1910-06-01   9.10      0.46      0.74                  9.90
# ..          ...    ...       ...       ...                   ...
# 823  1939-08-01  11.54      0.55      0.79                 13.80
# 824  1939-09-01  12.77      0.56      0.81                 14.10
# 825  1939-10-01  12.90      0.58      0.84                 14.00
# 826  1939-11-01  12.67      0.60      0.87                 14.00
# 827  1939-12-01  12.37      0.62      0.90                 14.00
#
#      Long Interest Rate  Real Price  Real Dividend  Real Earnings   PE10  \
# 469                3.92      245.41          11.24          19.06  14.00
# ...

# %%
fig,ax=plt.subplots(figsize=(10,10))
crisi["SP500"].plot(ax=ax)
plt.show()

# %%
cr=crisi.copy()
crisi["Date_"]=crisi["Date"]
crisi
# Out:
# /tmp/ipykernel_4232/245017208.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crisi["Date_"]=crisi["Date"]
#            Date  SP500  Dividend  Earnings  Consumer Price Index  \
# 469  1910-02-01   9.72      0.45      0.76                  9.90
# 470  1910-03-01   9.96      0.45      0.75                 10.09
# 471  1910-04-01   9.72      0.45      0.75                 10.18
# 472  1910-05-01   9.56      0.45      0.75                  9.99
# 473  1910-06-01   9.10      0.46      0.74                  9.90
# ..          ...    ...       ...       ...                   ...
# 823  1939-08-01  11.54      0.55      0.79                 13.80
# 824  1939-09-01  12.77      0.56      0.81                 14.10
# ...

# %%
crisi=crisi.set_index("Date_")
crisi
# Out:
#                   Date  SP500  Dividend  Earnings  Consumer Price Index  \
# Date_
# 1910-02-01  1910-02-01   9.72      0.45      0.76                  9.90
# 1910-03-01  1910-03-01   9.96      0.45      0.75                 10.09
# 1910-04-01  1910-04-01   9.72      0.45      0.75                 10.18
# 1910-05-01  1910-05-01   9.56      0.45      0.75                  9.99
# 1910-06-01  1910-06-01   9.10      0.46      0.74                  9.90
# ...                ...    ...       ...       ...                   ...
# 1939-08-01  1939-08-01  11.54      0.55      0.79                 13.80
# 1939-09-01  1939-09-01  12.77      0.56      0.81                 14.10
# 1939-10-01  1939-10-01  12.90      0.58      0.84                 14.00
# 1939-11-01  1939-11-01  12.67      0.60      0.87                 14.00
# 1939-12-01  1939-12-01  12.37      0.62      0.90                 14.00
#
#             Long Interest Rate  Real Price  Real Dividend  Real Earnings  \
# Date_
# ...

# %%
fig,ax=plt.subplots(figsize=(13,5))
crisi["SP500"].plot(ax=ax)
plt.show()

# %% [markdown]
# # BITCOIN

# %%
bitdf=pd.read_csv("bitcoin_csv.csv",index_col="date")
bitdf
# Out:
#             txVolume(USD)  adjustedTxVolume(USD)  txCount  marketcap(USD)  \
# date
# 2009-01-09            NaN                    NaN        0             NaN
# 2009-01-10            NaN                    NaN        0             NaN
# 2009-01-11            NaN                    NaN        0             NaN
# 2009-01-12            NaN                    NaN        7             NaN
# 2009-01-13            NaN                    NaN        0             NaN
# ...                   ...                    ...      ...             ...
# 2018-11-18   1.976557e+09           1.304067e+09   239680    9.664468e+10
# 2018-11-19   4.480410e+09           2.620049e+09   267845    9.771459e+10
# 2018-11-20   5.838062e+09           3.944652e+09   288318    8.456520e+10
# 2018-11-21   3.406311e+09           2.220358e+09   254837    7.764452e+10
# 2018-11-22   2.759416e+09           1.711484e+09   265994    8.019071e+10
#
#             price(USD)  exchangeVolume(USD)  generatedCoins       fees  \
# ...

# %%
bitdf.dropna(inplace=True)
bitdf
# Out:
#             txVolume(USD)  adjustedTxVolume(USD)  txCount  marketcap(USD)  \
# date
# 2013-04-28   6.879868e+07           3.153714e+07    41702    1.500656e+09
# 2013-04-29   1.138128e+08           4.821652e+07    51602    1.491703e+09
# 2013-04-30   8.426632e+07           5.686790e+07    47450    1.598310e+09
# 2013-05-01   1.206825e+08           8.208736e+07    55176    1.543334e+09
# 2013-05-02   9.337533e+07           5.823736e+07    55295    1.292577e+09
# ...                   ...                    ...      ...             ...
# 2018-11-18   1.976557e+09           1.304067e+09   239680    9.664468e+10
# 2018-11-19   4.480410e+09           2.620049e+09   267845    9.771459e+10
# 2018-11-20   5.838062e+09           3.944652e+09   288318    8.456520e+10
# 2018-11-21   3.406311e+09           2.220358e+09   254837    7.764452e+10
# 2018-11-22   2.759416e+09           1.711484e+09   265994    8.019071e+10
#
#             price(USD)  exchangeVolume(USD)  generatedCoins       fees  \
# ...

# %%
fig,ax=plt.subplots(figsize=(13,5))
bitdf["price(USD)"].plot(ax=ax)
plt.show()

# %%
bitdf["prezzo_return"]=(bitdf['price(USD)']-bitdf['price(USD)'].shift(1))/bitdf['price(USD)'].shift(1)
bitdf["prezzo_return"]
# Out:
# date
# 2013-04-28         NaN
# 2013-04-29   -0.006356
# 2013-04-30    0.071110
# 2013-05-01   -0.034722
# 2013-05-02   -0.162734
#                 ...
# 2018-11-18   -0.003377
# 2018-11-19    0.010979
# 2018-11-20   -0.134652
# 2018-11-21   -0.081907
# 2018-11-22    0.032702
# Name: prezzo_return, Length: 2035, dtype: float64

# %%
fig,ax=plt.subplots(figsize=(10,6))
bitdf["prezzo_return"].plot(ax=ax)
plt.show()

# %% [markdown]
# # H&M DATASET

# %%
articlesdf=pd.read_csv("articles.csv")
articlesdf
# Out:
#         article_id  product_code               prod_name  product_type_no  \
# 0        108775015        108775               Strap top              253
# 1        108775044        108775               Strap top              253
# 2        108775051        108775           Strap top (1)              253
# 3        110065001        110065       OP T-shirt (Idro)              306
# 4        110065002        110065       OP T-shirt (Idro)              306
# ...            ...           ...                     ...              ...
# 105537   953450001        953450  5pk regular Placement1              302
# 105538   953763001        953763       SPORT Malaga tank              253
# 105539   956217002        956217         Cartwheel dress              265
# 105540   957375001        957375        CLAIRE HAIR CLAW               72
# 105541   959461001        959461            Lounge dress              265
#
#        product_type_name  product_group_name  graphical_appearance_no  \
# ...

# %% [markdown]
# # FELICITA

# %%
happy2015=pd.read_csv("2015.csv")
happy2016=pd.read_csv("2016.csv")
happy2017=pd.read_csv("2017.csv")
happy2018=pd.read_csv("2018.csv")
happy2019=pd.read_csv("2019.csv")
happy=pd.concat([happy2015,happy2016,happy2017,happy2018,happy2019])
happy
# Out:
#          Country          Region  Happiness Rank  Happiness Score  \
# 0    Switzerland  Western Europe             1.0            7.587
# 1        Iceland  Western Europe             2.0            7.561
# 2        Denmark  Western Europe             3.0            7.527
# 3         Norway  Western Europe             4.0            7.522
# 4         Canada   North America             5.0            7.427
# ..           ...             ...             ...              ...
# 151          NaN             NaN             NaN              NaN
# 152          NaN             NaN             NaN              NaN
# 153          NaN             NaN             NaN              NaN
# 154          NaN             NaN             NaN              NaN
# 155          NaN             NaN             NaN              NaN
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# 1           0.04884                   1.30232  1.40223
# ...

# %%
happy_perrichhezza=happy[["Happiness Score","Economy (GDP per Capita)","Country"]].dropna()
happy_perrichhezza
# Out:
#      Happiness Score  Economy (GDP per Capita)      Country
# 0              7.587                   1.39651  Switzerland
# 1              7.561                   1.30232      Iceland
# 2              7.527                   1.32548      Denmark
# 3              7.522                   1.45900       Norway
# 4              7.427                   1.32629       Canada
# ..               ...                       ...          ...
# 152            3.484                   0.39499        Benin
# 153            3.360                   0.38227  Afghanistan
# 154            3.303                   0.28123         Togo
# 155            3.069                   0.74719        Syria
# 156            2.905                   0.06831      Burundi
#
# [315 rows x 3 columns]

# %%
countries=happy_perrichhezza["Country"].values
x=happy_perrichhezza["Happiness Score"].values
y=happy_perrichhezza["Economy (GDP per Capita)"].values

# %%
fig,ax=plt.subplots(figsize=(18,18))
ax.scatter(happy_perrichhezza["Happiness Score"],happy_perrichhezza["Economy (GDP per Capita)"])
for posx,posy,C in zip(x,y,countries):
    ax.annotate(C,(posx,posy), fontsize=8)
ax.set_ylim([0.75,1.75])
ax.set_xlim([5,8])
plt.show()
