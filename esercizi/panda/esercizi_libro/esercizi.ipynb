# %% [markdown]
# # ES 6 PAG 153

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# carica il file csv in un dataframe
df = pd.read_csv('valutazioni.csv')
df
# Out:
#      Nome_Materia  Valutazione
# 0      Matematica            8
# 1        Italiano            9
# 2         Inglese            7
# 3  Sistemi e reti            6
# 4           tpsit            8
# 5   microrobotica            7
# 6            GPOI            7
# 7         Motoria            7

# %% [markdown]
# # ES 5 PAG 153

# %%
dfval=pd.read_csv("registro_voti.csv")
dfval
# Out:
#         Cognome  Valutazione1  Valutazione2
# 0      adelardi           4.1           3.1
# 1        adessi           8.0           3.3
# 2         aggio           5.2           4.6
# 3       allegri           6.3           3.8
# 4       armadei           7.2           5.0
# 5        baglio           NaN           7.0
# 6      benetton           6.5           4.4
# 7   bergamaschi           8.5           2.1
# 8         bosco           5.2           3.3
# 9        capone           7.7           3.0
# 10      de luca           6.5           6.1
# 11        detti           6.0           7.6
# 12    di donato           5.7           5.7
# 13      fallaci           NaN           2.6
# 14      fanucci           8.1           5.6
# 15   fiorentino           4.2           4.3
# 16      gentile           2.1           3.1
# 17     marcello           9.3           6.7
# 18     montalto           8.6           4.6
# 19      moretti           9.0           5.3
# ...

# %%
min1=dfval["Valutazione1"].min()
min2=dfval["Valutazione2"].min()
print(min1)
print(min2)
# Out:
# 2.1
# 2.1

# %%
mean1=dfval["Valutazione1"].mean()
mean2=dfval["Valutazione2"].mean()
print(mean1)
print(mean2)
# Out:
# 6.13076923076923
# 4.544444444444445

# %%
max1=dfval["Valutazione1"].max()
max2=dfval["Valutazione2"].max()
print(max1)
print(max2)
# Out:
# 9.3
# 7.6

# %% [markdown]
# # ES7 PAG 153

# %%
neodf=pd.read_json("neowise.json")
neodf
# Out:
#              designation           discovery_date  h_mag  moid_au  q_au_1  \
# 0     419880 (2011 AH37)  2011-01-07T00:00:00.000   19.7    0.035    0.84
# 1     419624 (2010 SO16)  2010-09-17T00:00:00.000   20.5    0.028    0.93
# 2    414772 (2010 OC103)  2010-07-28T00:00:00.000   19.0    0.333    0.39
# 3     414746 (2010 EH20)  2010-03-06T00:00:00.000   18.0    0.268    1.25
# 4    407324 (2010 OB101)  2010-07-18T00:00:00.000   20.7    0.111    0.77
# ..                   ...                      ...    ...      ...     ...
# 197           (2010 CO1)  2010-02-01T00:00:00.000   21.5    0.023    0.79
# 198     P/2010 B2 (WISE)  2010-01-22T00:00:00.000    NaN    0.630    1.62
# 199         (2010 AU118)  2010-01-13T00:00:00.000   17.7    0.147    1.13
# 200          (2010 AG79)  2010-01-13T00:00:00.000   19.9    0.244    1.22
# 201          (2010 AB78)  2010-01-12T00:00:00.000   18.3    0.206    1.02
#
#      q_au_2  period_yr  i_deg  pha       orbit_class
# ...

# %%
media=neodf[["orbit_class","period_yr"]].groupby("orbit_class").mean()
media
# Out:
#                            period_yr
# orbit_class
# Amor                        5.235082
# Apollo                      2.941143
# Aten                        0.891333
# Comet                  238220.625556
# Encke-type Comet            5.490000
# Halley-type Comet*         23.375000
# Jupiter-family Comet        8.380000
# Jupiter-family Comet*      17.300000
# Parabolic Comet                  NaN

# %%
fig, ax=plt.subplots(figsize=(10,10))
ax.scatter(neodf["moid_au"],neodf["period_yr"])
plt.show()

# %% [markdown]
#  # ES 8 PAG 153

# %%
pengdf=pd.read_csv("../penguins_size.csv")
pengdf
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
species=pengdf[["island","species"]].value_counts()
species
# Out:
# island     species
# Biscoe     Gentoo       124
# Dream      Chinstrap     68
#            Adelie        56
# Torgersen  Adelie        52
# Biscoe     Adelie        44
# dtype: int64

# %% [markdown]
# # ES 9 PAG 153

# %%
femmine=pengdf[pengdf["sex"]=="FEMALE"]
femmine
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 4    Adelie  Torgersen              36.7             19.3              193.0
# 6    Adelie  Torgersen              38.9             17.8              181.0
# 12   Adelie  Torgersen              41.1             17.6              182.0
# ..      ...        ...               ...              ...                ...
# 332  Gentoo     Biscoe              43.5             15.2              213.0
# 334  Gentoo     Biscoe              46.2             14.1              217.0
# 338  Gentoo     Biscoe              47.2             13.7              214.0
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
#
#      body_mass_g     sex
# ...

# %%
femmine_sotto3700=femmine[femmine["body_mass_g"]<3700.0]
femmine_sotto3700
# Out:
#        species     island  culmen_length_mm  culmen_depth_mm  \
# 2       Adelie  Torgersen              40.3             18.0
# 4       Adelie  Torgersen              36.7             19.3
# 6       Adelie  Torgersen              38.9             17.8
# 12      Adelie  Torgersen              41.1             17.6
# 16      Adelie  Torgersen              38.7             19.0
# ..         ...        ...               ...              ...
# 208  Chinstrap      Dream              45.2             16.6
# 211  Chinstrap      Dream              45.6             19.4
# 213  Chinstrap      Dream              46.8             16.5
# 214  Chinstrap      Dream              45.7             17.0
# 216  Chinstrap      Dream              43.5             18.1
#
#      flipper_length_mm  body_mass_g     sex
# 2                195.0       3250.0  FEMALE
# 4                193.0       3450.0  FEMALE
# 6                181.0       3625.0  FEMALE
# 12               182.0       3200.0  FEMALE
# ...

# %%
femmine_sotto3700_gentoo=femmine_sotto3700[femmine_sotto3700["species"]=="Gentoo"]["species"]
femmine_sotto3700_gentoo
# Out:
# Series([], Name: species, dtype: object)

# %%
pengdf[(pengdf['species']=='Adelie')]['flipper_length_mm'].mean()
# Out:
# 189.95364238410596

# %%
pengdf[(pengdf['species']=='Adelie')& (pengdf["sex"]=='MALE')]['flipper_length_mm'].mean()
# Out:
# 192.41095890410958

# %%
pengdf[(pengdf['species']=='Adelie')& (pengdf["sex"]=='MALE')]['body_mass_g'].min()
# Out:
# 3325.0
