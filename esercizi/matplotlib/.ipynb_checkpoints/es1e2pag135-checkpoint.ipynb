# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.linspace(-1,1,200)
F1=x**2
F2=x**3
F3=x**4
F3
# Out:
# array([1.00000000e+00, 9.60400990e-01, 9.21989850e-01, 8.84742583e-01,
#        8.48635438e-01, 8.13644908e-01, 7.79747733e-01, 7.46920893e-01,
#        7.15141619e-01, 6.84387382e-01, 6.54635900e-01, 6.25865136e-01,
#        5.98053297e-01, 5.71178836e-01, 5.45220449e-01, 5.20157078e-01,
#        4.95967911e-01, 4.72632379e-01, 4.50130159e-01, 4.28441172e-01,
#        4.07545584e-01, 3.87423807e-01, 3.68056496e-01, 3.49424552e-01,
#        3.31509122e-01, 3.14291596e-01, 2.97753608e-01, 2.81877041e-01,
#        2.66644018e-01, 2.52036909e-01, 2.38038330e-01, 2.24631141e-01,
#        2.11798446e-01, 1.99523594e-01, 1.87790179e-01, 1.76582042e-01,
#        1.65883266e-01, 1.55678180e-01, 1.45951358e-01, 1.36687618e-01,
#        1.27872024e-01, 1.19489885e-01, 1.11526752e-01, 1.03968426e-01,
#        9.68009478e-02, 9.00106061e-02, 8.35839334e-02, 7.75077073e-02,
#        7.17689501e-02, 6.63549291e-02, 6.12531564e-02, 5.64513889e-02,
# ...

# %%
plt.plot(x,F1,label="funzione x")
plt.plot(x,F2,label="funzione x^2")
plt.plot(x,F3,label="Funzione x^3")
plt.xlabel("ascissa")
plt.ylabel("ordinata")
plt.title("Grafico delle funzioni")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # ESERCIZIO 2

# %%
x=np.linspace(-1,1,200)
F1=(1/2)*x
F2=x
F3=2*x
F4=4*x
plt.plot(x,F1,label="funzione x")
plt.plot(x,F2,label="funzione x^2")
plt.plot(x,F3,label="Funzione x^3")
plt.plot(x,F4,label="funzione")
plt.xlabel("ascissa")
plt.ylabel("ordinata")
plt.title("Grafico delle funzioni")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
