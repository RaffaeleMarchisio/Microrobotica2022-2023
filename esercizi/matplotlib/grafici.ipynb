# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.linspace(-1,1,101)
f1=1/x
# Out:
# /tmp/ipykernel_3507/2060554471.py:2: RuntimeWarning: divide by zero encountered in true_divide
#   f1=1/x

# %%
fig,ax=plt.subplots(figsize=(6,6))
ax.plot(x,f1)
ax.grid("both")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
